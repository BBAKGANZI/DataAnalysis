# %% [markdown]
# # 인구소멸위기지역 - 시각화(Part3)

# %%
# !apt-get install -y fonts-nanum > /dev/null
# !fc-cache -fv > /dev/null
# !rm -rf ~/.cache/matplotlib > /dev/null
# 런타임 다시시작

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='NanumBarunGothic')

# %%
from google.colab import drive
drive.mount('/content/mnt')
# Out:
# Mounted at /content/mnt

# %%
data_folder = '/content/mnt/MyDrive/데이터/인구소멸위기지역'
pop = pd.read_csv(f'{data_folder}/시군구_ID부여.csv', encoding='euc-kr')
pop.head()
# Out:
#   광역시도  시군구  20~39세계  20~39세여자  ...      소멸비율  소멸위기지역  소멸위기고위험지역      ID
# 0  강원도  강릉시    47006     21807  ...  0.497536    True      False      강릉
# 1  강원도  고성군     5217      2042  ...  0.263314    True      False  고성(강원)
# 2  강원도  동해시    18727      8258  ...  0.469952    True      False      동해
# 3  강원도  삼척시    13583      6117  ...  0.380481    True      False      삼척
# 4  강원도  속초시    18080      8171  ...  0.538629   False      False      속초
#
# [5 rows x 12 columns]

# %% [markdown]
# ## 지도 모양 보기

# %%
map_raw = pd.read_excel(f'{data_folder}/draw_korea_raw(2021).xlsx')
map_raw
# Out:
#        0      1       2       3       4   ...     9       10     11      12   13
# 0     NaN    NaN     NaN     NaN     NaN  ...     양구  고성(강원)    NaN     NaN  NaN
# 1     NaN    NaN     NaN      양주     동두천  ...     춘천      속초    NaN     NaN  NaN
# 2     NaN    NaN     NaN      파주  고양 일산동  ...     횡성      양양    NaN     NaN  NaN
# 3     NaN    NaN     NaN  고양 일산서   고양 덕양  ...     하남      정선     강릉     NaN  NaN
# 4     NaN    NaN      김포      광명   서울 은평  ...     양평      태백     동해     NaN  NaN
# 5     NaN  인천 강화      부천   안양 만안   서울 강서  ...     여주      원주     삼척     NaN  NaN
# 6     NaN  인천 서구   인천 동구   안양 동안   서울 양천  ...     이천      평창     울진     NaN  NaN
# 7     NaN    NaN   인천 계양      시흥   서울 금천  ...     광주      영월     영덕     NaN  NaN
# 8     NaN    NaN   인천 부평   안산 상록   서울 구로  ...  용인 수지      문경     봉화     NaN   울릉
# 9     NaN  인천 중구  인천 미추홀   안산 단원      군포  ...  용인 처인      안동     영양     NaN  NaN
# 10  인천 옹진  인천 연수   인천 남동      화성      오산  ...     영주      구미     청송   포항 북구  NaN
# 11     태안     아산   천안 동남   천안 서북      평택  ...     김천      군위     의성   포항 남구  NaN
# 12    NaN     당진      홍성      예산      공주  ...     칠곡      영천     경산      경주  NaN
# 13    NaN     서산      보령      청양      세종  ...     고령      청도     성주   울산 북구  NaN
# 14    NaN    NaN      부여      논산      계룡  ...  대구 중구   대구 수성  울산 울주   울산 동구  NaN
# 15    NaN    NaN      서천      금산   대전 유성  ...  대구 남구   대구 동구  울산 중구   울산 남구  NaN
# 16    NaN    NaN      군산      익산   대전 서구  ...  대구 달성   부산 금정  부산 동래   부산 기장  NaN
# 17    NaN    NaN      부안      김제      완주  ...  부산 북구  부산 부산진  부산 연제  부산 해운대  NaN
# 18    NaN     고창      정읍   전주 덕진      진안  ...  부산 사상   부산 동구  부산 중구     NaN  NaN
# 19    NaN     영광      장성   전주 완산      임실  ...  부산 서구   부산 사하  부산 남구     NaN  NaN
# 20    NaN     함평      담양      순창      구례  ...     김해   부산 영도  부산 수영     NaN  NaN
# 21     신안     무안   광주 광산      곡성      화순  ...    NaN     NaN    NaN     NaN  NaN
# 22     목포     나주   광주 서구   광주 북구      순천  ...    NaN     NaN    NaN     NaN  NaN
# 23     해남     영암   광주 남구   광주 동구      여수  ...    NaN     NaN    NaN     NaN  NaN
# 24     진도     강진      장흥      보성     NaN  ...    NaN     NaN    NaN     NaN  NaN
# 25    NaN    NaN      완도     NaN     NaN  ...    NaN     NaN    NaN     NaN  NaN
# 26    NaN    NaN     NaN     NaN     NaN  ...    NaN     NaN    NaN     NaN  NaN
#
# [27 rows x 14 columns]

# %%
map_raw.stack()[:10]
# Out:
# 0  7         철원
#    8         화천
#    9         양구
#    10    고성(강원)
# 1  3         양주
#    4        동두천
#    5         연천
#    6         포천
#    7        의정부
#    8         인제
# dtype: object

# %%
map = pd.DataFrame(map_raw.stack())
map.reset_index(inplace=True)
print(map.shape)
map.head()
# Out:
# (250, 3)
#    level_0  level_1       0
# 0        0        7      철원
# 1        0        8      화천
# 2        0        9      양구
# 3        0       10  고성(강원)
# 4        1        3      양주

# %%
map.columns = ['y', 'x', 'ID']
map.head()
# Out:
#    y   x      ID
# 0  0   7      철원
# 1  0   8      화천
# 2  0   9      양구
# 3  0  10  고성(강원)
# 4  1   3      양주

# %%
# !cp $data_folder/draw_map.py .

# %%
# !ls -l
# Out:
# total 20
# -rw------- 1 root root 5269 Sep  6 05:16 draw_map.py
# drwx------ 5 root root 4096 Sep  6 04:02 mnt
# drwxr-xr-x 2 root root 4096 Sep  6 04:24 __pycache__
# drwxr-xr-x 1 root root 4096 Sep  1 19:26 sample_data

# %%
from draw_map import BORDER_LINES, drawKorea, drawKoreaMinus

# %%
plt.figure(figsize=(8, 11))

# 지역 이름 표시

for idx, row in map.iterrows():  # =  for i in map.index:
                                 #    print(map.ID[i])
    # 광역시는 구 이름이 겹치는 경우가 많아서 광역시 이름도 같이 표시 
    # (중구, 서구 등)
    if len(row.ID.split())==2:
        dispname = f'{row.ID.split()[0]}\n{row.ID.split()[1]}'
    elif row.ID[:2]=='고성':
        dispname = '고성'
    else:
        dispname = row.ID

    # 서대문구, 서귀포시 같이 이름이 3자 이상인 경우에 작은 글자로 표시
    if len(dispname.splitlines()[-1]) >= 3:
        fontsize, linespacing = 9.5, 1.5
    else:
        fontsize, linespacing = 11, 1.2

    plt.annotate(dispname, (row['x']+0.5, row['y']+0.5), weight='bold',
                 fontsize=fontsize, ha='center', va='center', 
                 linespacing=linespacing)
    
# 시도 경계
for path in BORDER_LINES:
    ys, xs = zip(*path)
    plt.plot(xs, ys, c='black', lw=1.5)

plt.gca().invert_yaxis()
#plt.gca().set_aspect(1)

plt.axis('off')

plt.tight_layout()
plt.show()

# %%
pop = pd.merge(pop, map, how='left', on='ID')
print(pop.shape)
pop.head()
# Out:
# (250, 14)
#   광역시도  시군구  20~39세계  20~39세여자  65세이상계  ...  소멸위기지역  소멸위기고위험지역      ID  y   x
# 0  강원도  강릉시    47006     21807   43830  ...    True      False      강릉  3  11
# 1  강원도  고성군     5217      2042    7755  ...    True      False  고성(강원)  0  10
# 2  강원도  동해시    18727      8258   17572  ...    True      False      동해  4  11
# 3  강원도  삼척시    13583      6117   16077  ...    True      False      삼척  5  11
# 4  강원도  속초시    18080      8171   15170  ...   False      False      속초  1  10
#
# [5 rows x 14 columns]

# %%
# Null 데이터가 있는지 확인
pop.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## 인구 현황 미치 이니구 소멸 위기지역 확인

# %% [markdown]
# - 시군구별 인구

# %%
drawKorea('인구수계', pop, 'Oranges')      # Reds, Greens, Oranges, Greys,

# %% [markdown]
# - 인구소멸 위기지역

# %%
drawKorea('소멸비율', pop, 'Greys')

# %%
pop['소멸위기지역'] = pop.소멸위기지역.astype(int)
drawKorea('소멸위기지역', pop, 'Reds')

# %% [markdown]
# - 여성인구 확인

# %%
pop['여성비'] = (pop['인구수여자'] / pop['인구수계'] - 0.5) * 100
drawKorea('여성비', pop, 'RdBu')

# %% [markdown]
# - 20, 30대 여성비

# %%
pop['2030여성비'] = (pop['20~39세여자'] / pop['20~39세계'] - 0.5 ) * 100
drawKoreaMinus('2030여성비', pop, 'RdBu_r')

# %% [markdown]
# ## Folium 지도에서 인구소멸 위기지역 표시하기

# %%
import folium
import json

# %%
pop.set_index('ID', inplace=True)
pop.head()
# Out:
#        광역시도  시군구  20~39세계  20~39세여자  ...  y   x       여성비    2030여성비
# ID                                   ...
# 강릉      강원도  강릉시    47006     21807  ...  3  11  0.376341  -3.608050
# 고성(강원)  강원도  고성군     5217      2042  ...  0  10 -1.746790 -10.858731
# 동해      강원도  동해시    18727      8258  ...  4  11 -0.740419  -5.903241
# 삼척      강원도  삼척시    13583      6117  ...  5  11 -0.706307  -4.965766
# 속초      강원도  속초시    18080      8171  ...  1  10  0.535603  -4.806416
#
# [5 rows x 15 columns]

# %%
geo_data = json.load(open(f'{data_folder}/skorea_municipalities_geo_simple.json'))

map = folium.Map(location=[35.9902, 127.054], zoom_start=7)
folium.Choropleth(
    geo_data=geo_data,
    data=pop.인구수계,
    columns=(pop.index, pop.인구수계),
    key_on='feature.id',
    fill_color='YlGnBu',
    legend_name='인구수'
).add_to(map)

title = '<h3 align="center" style="font-size:20px">기초자치단체별 인구수</h3>'
map.get_root().html.add_child(folium.Element(title))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_586a3d11050b4adea4d7bedd2b449e81%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%3Ch3%20align%3D%22center%22%20style%3D%22font-size%3A20px%22%3E%EA%B8%B0%EC%B4%88%EC%9E%90%EC%B9%98%EB%8B%A8%EC%B2%B4%EB%B3%84%20%EC%9D%B8%EA%B5%AC%EC%88%98%3C/h3%3E%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_586a3d11050b4adea4d7bedd2b449e81%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_586a3d11050b4adea4d7bedd2b449e81%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_586a3d11050b4adea4d7bedd2b449e81%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B35.9902%2C%20127.054%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%207%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20% ...

# %% [markdown]
# - 인구소멸 위기지역

# %%
geo_data = json.load(open(f'{data_folder}/skorea_municipalities_geo_simple.json'))

map = folium.Map(location=[35.9902, 127.054], zoom_start=7)
folium.Choropleth(
    geo_data=geo_data,
    data=pop.소멸위기지역,
    columns=(pop.index, pop.소멸위기지역),
    key_on='feature.id',
    fill_color='YlGnBu'
).add_to(map)

title = '<h3 align="center" style="font-size:20px">소멸위기지역</h3>'
map.get_root().html.add_child(folium.Element(title))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_3cddc74ccbd848dca106fb9d51151460%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%3Ch3%20align%3D%22center%22%20style%3D%22font-size%3A20px%22%3E%EC%86%8C%EB%A9%B8%EC%9C%84%EA%B8%B0%EC%A7%80%EC%97%AD%3C/h3%3E%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3cddc74ccbd848dca106fb9d51151460%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_3cddc74ccbd848dca106fb9d51151460%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_3cddc74ccbd848dca106fb9d51151460%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B35.9902%2C%20127.054%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%207%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_771bd572ee3543 ...
